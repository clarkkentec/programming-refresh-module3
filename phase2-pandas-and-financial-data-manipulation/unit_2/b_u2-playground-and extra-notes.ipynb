# %%
#Core Concepts


#       __ .loc(()) vs .iloc() __
#   SYNTAX: df.loc[row_labels, column_labels] -> This is label based selection
#   you can pull through numerous data points single/all rows/columns, or even a series


#   SYNTAX: df.iloc[row_positions, column_positions] -> This is position-based selection
#   you can pull through data points through the index location - similar to m3-indexing-and-slicing as in phase1
#   rarely would you use this

#       __ BOOLEAN MASKS __
#   This is creating a condition (T/F) where it returns data points where they are true
#   Similar in part to what I already do with SQL
#   # SYNTAX: 
#       mask = df[label] condition  -> creating the condition
#       df[mask]                    -> using the condition
#       alternatively you can jump straight to using the condition: df[condition]


#       __ Watch out for SettingWithCopyWarning __
